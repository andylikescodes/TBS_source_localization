# %%
import mne
import os

# %%
data = mne.io.read_raw_brainvision("../data/Jake/Session_1/TBS_pilot000002_s1.vhdr")
# Out:
# Extracting parameters from ../data/Jake/Session_1/TBS_pilot000002_s1.vhdr...
# Setting channel info structure...
# /tmp/ipykernel_24742/585008151.py:1: RuntimeWarning: No coordinate information found for channels ['R Hand', 'VEOG', 'HEOG']. Setting channel types to misc. To avoid this warning, set channel types explicitly.
#   data = mne.io.read_raw_brainvision("../data/Jake/Session_1/TBS_pilot000002_s1.vhdr")
# /tmp/ipykernel_24742/585008151.py:1: RuntimeWarning: Not setting positions of 3 misc channels found in montage:
# ['R Hand', 'VEOG', 'HEOG']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   data = mne.io.read_raw_brainvision("../data/Jake/Session_1/TBS_pilot000002_s1.vhdr")

# %%
data.info
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, Pz, P3, ...
#  chs: 63 EEG, 3 misc
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 690.0 Hz
#  meas_date: 2022-11-29 16:50:08 UTC
#  nchan: 66
#  projs: []
#  sfreq: 2500.0 Hz
# >

# %%
chan_location = mne.channels.read_dig_captrak("../data/Jake/Session_1/CapTrakResultFile_Pilot02_session01.bvct")
plt = chan_location.plot()

# %%
import matplotlib.pyplot as plt
plt.clf()
fig = chan_location.plot(kind="3d", show=False)
fig = fig.gca().view_init(azim=70, elev=15)  # set view angle for tutorial
plt.show()

# %%
data.info['ch_names']
# Out:
# ['Fp1',
#  'Fz',
#  'F3',
#  'F7',
#  'FT9',
#  'FC5',
#  'FC1',
#  'C3',
#  'T7',
#  'TP9',
#  'CP5',
#  'CP1',
#  'Pz',
#  'P3',
#  'P7',
#  'O1',
#  'O2',
#  'P4',
#  'P8',
#  'TP10',
#  'CP6',
#  'CP2',
#  'Cz',
#  'C4',
#  'T8',
#  'FT10',
#  'FC6',
#  'FC2',
#  'F4',
#  'F8',
#  'Fp2',
#  'AF7',
#  'AF3',
#  'AFz',
#  'F1',
#  'F5',
#  'FT7',
#  'FC3',
#  'C1',
#  'C5',
#  'TP7',
#  'CP3',
#  'P1',
#  'P5',
#  'PO7',
#  'PO3',
#  'POz',
#  'PO4',
#  'PO8',
#  'P6',
#  'P2',
#  'CPz',
#  'CP4',
#  'TP8',
#  'C6',
#  'C2',
#  'FC4',
#  'FT8',
#  'F6',
#  'AF8',
#  'AF4',
#  'F2',
#  'FCz',
#  'R Hand',
#  'VEOG',
#  'HEOG']

# %%
data.pick(['FCz','Cz']).plot_psd(fmax=60)
# Out:
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 0.102 (s)
# <MNELineFigure size 1000x350 with 2 Axes>
